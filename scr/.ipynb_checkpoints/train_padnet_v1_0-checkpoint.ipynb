# %%
import tensorflow as tf
import keras
import keras.backend as K
import keras.layers as KL
import keras.initializers as KI
import keras.engine as KE
import keras.models as KM
import numpy as np
import os
import cv2
import skimage
import h5py
import sys
sys.path.append('..')
from cfg.config import Config
import utils.matterport_utils as matterport_utils
import utils.matterport_visualize as matterport_visualize
from models import data_generator, model_misc
from models.padnet_v1_0 import PADNet
from utils.misc import load_weights_from_hdf5_group_by_name
from dataIO.a2d_dataset import A2DDataset

from distutils.version import LooseVersion
assert LooseVersion(tf.__version__) >= LooseVersion("1.3")
assert LooseVersion(keras.__version__) >= LooseVersion('2.0.8')

os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"
print(os.getenv('CUDA_VISIBLE_DEVICES'))
# Out:
# /vision/u/jingweij/Softwares/anaconda2/envs/pad/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 0,1,2,3

# %%
class A2DConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "a2d"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 4
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_ACTOR_CLASSES = 1 + 7  # background + 7 objects
    NUM_ACTION_CLASSES = 9

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (16, 32, 64, 128, 256)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 64

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 1000

    # use small validation steps since the epoch is small
    VALIDATION_STPES = 100

    TIMESTEPS = 8

    BATCH_SIZE = IMAGES_PER_GPU * GPU_COUNT
    IMAGE_H = 256
    IMAGE_W = 256
    IMAGE_SHAPE = np.array([IMAGE_H, IMAGE_W, 3])
    RGB_CLIP_SHAPE = np.array([TIMESTEPS, IMAGE_H, IMAGE_W, 3])
    FLOW_CLIP_SHAPE = np.array([TIMESTEPS, IMAGE_H, IMAGE_W, 2])
    
config = A2DConfig()
config.display()
# Out:
# Configurations:
# BACKBONE_SHAPES                [[64 64]
#  [32 32]
#  [16 16]
#  [ 8  8]
#  [ 4  4]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FLOW_CLIP_SHAPE                [  8 256 256   2]
# GPU_COUNT                      4
# IMAGES_PER_GPU                 2
# IMAGE_H                        256
# IMAGE_MAX_DIM                  256
# IMAGE_MIN_DIM                  256
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [256 256   3]
# IMAGE_W                        256
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           a2d
# NUM_ACTION_CLASSES             9
# NUM_ACTOR_CLASSES              8
# NUM_CLASSES                    1
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# RGB_CLIP_SHAPE                 [  8 256 256   3]
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              2
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TIMESTEPS                      8
# TRAIN_ROIS_PER_IMAGE           64
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STPES               100
# WEIGHT_DECAY                   0.0001

# %%
# Training dataset
dataset_train = A2DDataset('train', '/vision/u/jingweij/Datasets/A2D/Release')
dataset_train.prepare()

# Validation dataset
dataset_val = A2DDataset('test', '/vision/u/jingweij/Datasets/A2D/Release')
dataset_val.prepare()

# %%
model = PADNet(mode='training', config=config, model_dir='../outputs/padnet_v1.0')

# %%
mrcnn_coco_pretrained_filename = '/vision/u/jingweij/VideoObjSeg/other_repos/Mask_RCNN/mask_rcnn_coco.h5'

# %%
layer_name_map = {}
all_layer_names = [x.name for x in model.keras_model.inner_model.layers]
for ln in all_layer_names:
    if ln.startswith('rgb_'):
        layer_name_map[ln] = ln.lstrip('rgb_')
    elif ln.startswith('flow_'):
        layer_name_map[ln] = ln.lstrip('flow_')

# %%
layer_name_map
# Out:
# {'flow_ROI': 'ROI',
#  'flow_magnitude': 'magnitude',
#  'flow_mrcnn_class_bn1': 'mrcnn_class_bn1',
#  'flow_mrcnn_class_conv1': 'mrcnn_class_conv1',
#  'flow_mrcnn_mask': 'mrcnn_mask',
#  'flow_mrcnn_mask_bn1': 'mrcnn_mask_bn1',
#  'flow_mrcnn_mask_bn2': 'mrcnn_mask_bn2',
#  'flow_mrcnn_mask_bn3': 'mrcnn_mask_bn3',
#  'flow_mrcnn_mask_bn4': 'mrcnn_mask_bn4',
#  'flow_mrcnn_mask_conv1': 'mrcnn_mask_conv1',
#  'flow_mrcnn_mask_conv2': 'mrcnn_mask_conv2',
#  'flow_mrcnn_mask_conv3': 'mrcnn_mask_conv3',
#  'flow_mrcnn_mask_conv4': 'mrcnn_mask_conv4',
#  'flow_mrcnn_mask_deconv': 'mrcnn_mask_deconv',
#  'flow_proposal_targets': 'proposal_targets',
#  'flow_resnet_3d': 'resnet_3d',
#  'flow_roi_align_classifier': 'roi_align_classifier',
#  'flow_roi_align_mask': 'roi_align_mask',
#  'flow_rpn_bbox': 'rpn_bbox',
#  'flow_rpn_class': 'rpn_class',
#  'flow_rpn_class_logits': 'rpn_class_logits',
#  'flow_rpn_model': 'rpn_model',
#  'flow_top_down': 'top_down',
#  'rgb_ROI': 'ROI',
#  'rgb_mrcnn_class_bn1': 'mrcnn_class_bn1',
#  'rgb_mrcnn_class_conv1': 'mrcnn_class_conv1',
#  'rgb_mrcnn_mask': 'mrcnn_mask',
#  'rgb_mrcnn_mask_bn1': 'mrcnn_mask_bn1',
#  'rgb_mrcnn_mask_bn2': 'mrcnn_mask_bn2',
#  'rgb_mrcnn_mask_bn3': 'mrcnn_mask_bn3',
#  'rgb_mrcnn_mask_bn4': 'mrcnn_mask_bn4',
#  'rgb_mrcnn_mask_conv1': 'mrcnn_mask_conv1',
#  'rgb_mrcnn_mask_conv2': 'mrcnn_mask_conv2',
#  'rgb_mrcnn_mask_conv3': 'mrcnn_mask_conv3',
#  'rgb_mrcnn_mask_conv4': 'mrcnn_mask_conv4',
#  'rgb_mrcnn_mask_deconv': 'mrcnn_mask_deconv',
#  'rgb_proposal_targets': 'proposal_targets',
#  'rgb_resnet_3d': 'esnet_3d',
#  'rgb_roi_align_classifier': 'oi_align_classifier',
#  'rgb_roi_align_mask': 'oi_align_mask',
#  'rgb_rpn_bbox': 'pn_bbox',
#  'rgb_rpn_class': 'pn_class',
#  'rgb_rpn_class_logits': 'pn_class_logits',
#  'rgb_rpn_model': 'pn_model',
#  'rgb_top_down': 'top_down'}

# %%
with h5py.File(mrcnn_coco_pretrained_filename, mode='r') as f:
    print('heads:')
    load_weights_from_hdf5_group_by_name(f, model.keras_model.inner_model.layers, layer_name_map, skip_mismatch=True)
    print('rgb resnet 3d spatial layers:')
    load_weights_from_hdf5_group_by_name(f, model.rgb_resnet_3d_model.layers)
    print('flow resnet 3d spatial layers:')
    load_weights_from_hdf5_group_by_name(f, model.flow_resnet_3d_model.layers)
    print('rgb top down:')
    load_weights_from_hdf5_group_by_name(f, model.rgb_top_down_model.layers)
    print('flow top down:')
    load_weights_from_hdf5_group_by_name(f, model.flow_top_down_model.layers)
    print('rgb rpn:')
    load_weights_from_hdf5_group_by_name(f, [model.r_rpn], {'rgb_rpn_model':'rpn_model'})
    print('flow rpn:')
    load_weights_from_hdf5_group_by_name(f, [model.f_rpn], {'flow_rpn_model':'rpn_model'})
# Out:
# heads:
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer mrcnn_bbox_fc due to mismatch in shape ((1024, 32) vs (1024, 324)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer mrcnn_bbox_fc due to mismatch in shape ((32,) vs (324,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_mrcnn_mask due to mismatch in shape ((1, 1, 256, 8) vs (1, 1, 256, 81)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_mrcnn_mask due to mismatch in shape ((8,) vs (81,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer flow_mrcnn_mask due to mismatch in shape ((1, 1, 256, 8) vs (1, 1, 256, 81)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer flow_mrcnn_mask due to mismatch in shape ((8,) vs (81,)).
#   weight_values[i].shape))
# ../utils/misc.py:92: UserWarning: Skipping loading of weights for layer mrcnn_mask due to mismatch in number of weights (0 vs 2).
#   ' ({} vs {}).'.format(len(symbolic_weights), len(weight_values)))
# ../utils/misc.py:128: UserWarning: conv1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: conv1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn_conv1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn_conv1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2a_branch1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2a_branch1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2b_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2b_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres2c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn2c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res2c_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn2c_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3a_branch1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3a_branch1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3b_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3b_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3c_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3c_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres3d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn3d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res3d_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn3d_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4a_branch1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4a_branch1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4b_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4b_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4c_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4c_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4d_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4d_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4e_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4e_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4e_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4e_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4e_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4e_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4f_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4f_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4f_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4f_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4f_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4f_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4g_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4g_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4g_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4g_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4g_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4g_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4h_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4h_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4h_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4h_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4h_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4h_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4i_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4i_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4i_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4i_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4i_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4i_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4j_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4j_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4j_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4j_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4j_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4j_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4k_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4k_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4k_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4k_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4k_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4k_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4l_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4l_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4l_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4l_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4l_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4l_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4m_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4m_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4m_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4m_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4m_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4m_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4n_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4n_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4n_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4n_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4n_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4n_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4o_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4o_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4o_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4o_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4o_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4o_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4p_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tres4p_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4p_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: tbn4p_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4p_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4p_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4q_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4q_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4q_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: bn4q_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: res4q_branch2b/kernel:0 is not loaded.
# ...
# ../utils/misc.py:128: UserWarning: fpn_c3p3/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c2p2/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c2p2/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p5/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p5/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p2/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p2/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p3/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p3/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p4/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p4/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c5p5_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c5p5_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c4p4_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c4p4_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c3p3_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c3p3_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c2p2_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_c2p2_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p5_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p5_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p2_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p2_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p3_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p3_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p4_1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: fpn_p4_1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_conv_shared/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_conv_shared/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_class_raw/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_class_raw/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_bbox_pred/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rpn_bbox_pred/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_actor_class_logits/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_actor_class_logits/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_action_class_logits/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_action_class_logits/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_bbox_fc/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: mrcnn_bbox_fc/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rgb_mrcnn_mask/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: rgb_mrcnn_mask/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: flow_mrcnn_mask/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:128: UserWarning: flow_mrcnn_mask/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# Weight value tuples:
# [(<tf.Variable 'rpn_conv_shared_1/kernel:0' shape=(3, 3, 256, 512) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 512), type "<f4">),
#  (<tf.Variable 'rpn_conv_shared_1/bias:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (512,), type "<f4">),
#  (<tf.Variable 'rpn_class_raw_1/kernel:0' shape=(1, 1, 512, 6) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (1, 1, 512, 6), type "<f4">),
#  (<tf.Variable 'rpn_class_raw_1/bias:0' shape=(6,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (6,), type "<f4">),
#  (<tf.Variable 'rpn_bbox_pred_1/kernel:0' shape=(1, 1, 512, 12) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (1, 1, 512, 12), type "<f4">),
#  (<tf.Variable 'rpn_bbox_pred_1/bias:0' shape=(12,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (12,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv1/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv1/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv1/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv1/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn1/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn1/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn1/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn1/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn1/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn1/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn1/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn1/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv2/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv2/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv2/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv2/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_conv1/kernel:0' shape=(7, 7, 256, 1024) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (7, 7, 256, 1024), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_conv1/bias:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_conv1/kernel:0' shape=(7, 7, 256, 1024) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (7, 7, 256, 1024), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_conv1/bias:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn2/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn2/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn2/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn2/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn2/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn2/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn2/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn2/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_bn1/gamma:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_bn1/beta:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_bn1/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_class_bn1/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_bn1/gamma:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_bn1/beta:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_bn1/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_class_bn1/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv3/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv3/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv3/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv3/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn3/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn3/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn3/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn3/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn3/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn3/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn3/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn3/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'mrcnn_class_conv2/kernel:0' shape=(1, 1, 1024, 1024) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (1, 1, 1024, 1024), type "<f4">),
#  (<tf.Variable 'mrcnn_class_conv2/bias:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'mrcnn_class_bn2/gamma:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'mrcnn_class_bn2/beta:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'mrcnn_class_bn2/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'mrcnn_class_bn2/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv4/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_conv4/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv4/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (3, 3, 256, 256), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_conv4/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn4/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn4/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn4/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_bn4/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn4/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn4/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn4/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_bn4/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_deconv/kernel:0' shape=(2, 2, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (2, 2, 256, 256), type "<f4">),
#  (<tf.Variable 'rgb_mrcnn_mask_deconv/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_deconv/kernel:0' shape=(2, 2, 256, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (2, 2, 256, 256), type "<f4">),
#  (<tf.Variable 'flow_mrcnn_mask_deconv/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">)]
# rgb resnet 3d spatial layers:
# flow resnet 3d spatial layers:
# rgb top down:
# flow top down:
# rgb rpn:
# flow rpn:
