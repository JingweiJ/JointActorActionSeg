# %%
import tensorflow as tf
import keras
import keras.backend as K
import keras.layers as KL
import keras.initializers as KI
import keras.engine as KE
import keras.models as KM
import numpy as np
import os
import cv2
import skimage
import h5py
import sys
sys.path.append('..')
from cfg.config import Config
import utils.matterport_utils as matterport_utils
import utils.matterport_visualize as matterport_visualize
from models import data_generator, model_misc
from models.padnet_v1_0 import PADNet
from utils.misc import load_weights_from_hdf5_group_by_name
from dataIO.a2d_dataset import A2DDataset

from distutils.version import LooseVersion
assert LooseVersion(tf.__version__) >= LooseVersion("1.3")
assert LooseVersion(keras.__version__) >= LooseVersion('2.0.8')

os.environ["CUDA_VISIBLE_DEVICES"] = "6"
print(os.getenv('CUDA_VISIBLE_DEVICES'))
# Out:
# /vision/u/jingweij/Softwares/anaconda2/envs/pad/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# 6

# %%
class A2DConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "a2d"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2

    # Number of classes (including background)
    NUM_ACTOR_CLASSES = 1 + 7  # background + 7 objects
    NUM_ACTION_CLASSES = 9

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (16, 32, 64, 128, 256)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 64

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 1000

    # use small validation steps since the epoch is small
    VALIDATION_STPES = 100

    TIMESTEPS = 8

    BATCH_SIZE = IMAGES_PER_GPU * GPU_COUNT
    IMAGE_H = 256
    IMAGE_W = 256
    IMAGE_SHAPE = np.array([IMAGE_H, IMAGE_W, 3])
    RGB_CLIP_SHAPE = np.array([TIMESTEPS, IMAGE_H, IMAGE_W, 3])
    FLOW_CLIP_SHAPE = np.array([TIMESTEPS, IMAGE_H, IMAGE_W, 2])
    
config = A2DConfig()
config.display()
# Out:
# Configurations:
# BACKBONE_SHAPES                [[64 64]
#  [32 32]
#  [16 16]
#  [ 8  8]
#  [ 4  4]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FLOW_CLIP_SHAPE                [  8 256 256   2]
# GPU_COUNT                      1
# IMAGES_PER_GPU                 2
# IMAGE_H                        256
# IMAGE_MAX_DIM                  256
# IMAGE_MIN_DIM                  256
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [256 256   3]
# IMAGE_W                        256
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.002
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           a2d
# NUM_ACTION_CLASSES             9
# NUM_ACTOR_CLASSES              8
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# RGB_CLIP_SHAPE                 [  8 256 256   3]
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              2
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TIMESTEPS                      8
# TRAIN_ROIS_PER_IMAGE           64
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STPES               100
# WEIGHT_DECAY                   0.0001

# %%
# Training dataset
dataset_train = A2DDataset('train', '/vision/u/jingweij/Datasets/A2D/Release')
dataset_train.prepare()

# Validation dataset
dataset_val = A2DDataset('test', '/vision/u/jingweij/Datasets/A2D/Release')
dataset_val.prepare()

# %%
# Build model
model = PADNet(mode='training', config=config, model_dir='../outputs/padnet_v1.0')

# %%
all_layers = model.keras_model.layers
all_layer_names = [x.name for x in all_layers]

# %%
all_layer_names
# Out:
# ['input_flow_clip',
#  'flow_magnitude',
#  'input_rgb_clip',
#  'concatenate_1',
#  'rgb_resnet_3d',
#  'input_labeled_frame_id',
#  'flow_resnet_3d',
#  'rgb_top_down',
#  'lambda_2',
#  'lambda_6',
#  'lambda_10',
#  'lambda_14',
#  'lambda_18',
#  'flow_top_down',
#  'lambda_4',
#  'lambda_8',
#  'lambda_12',
#  'lambda_16',
#  'lambda_20',
#  'multiply_1',
#  'multiply_3',
#  'multiply_5',
#  'multiply_7',
#  'multiply_9',
#  'multiply_2',
#  'multiply_4',
#  'multiply_6',
#  'multiply_8',
#  'multiply_10',
#  'lambda_3',
#  'lambda_7',
#  'lambda_11',
#  'lambda_15',
#  'lambda_19',
#  'lambda_5',
#  'lambda_9',
#  'lambda_13',
#  'lambda_17',
#  'lambda_21',
#  'rgb_rpn_model',
#  'flow_rpn_model',
#  'rgb_rpn_class',
#  'rgb_rpn_bbox',
#  'flow_rpn_class',
#  'flow_rpn_bbox',
#  'input_gt_boxes',
#  'rgb_ROI',
#  'lambda_1',
#  'input_gt_masks',
#  'flow_ROI',
#  'rgb_proposal_targets',
#  'flow_proposal_targets',
#  'rgb_roi_align_mask',
#  'flow_roi_align_mask',
#  'rgb_mrcnn_mask_conv1',
#  'flow_mrcnn_mask_conv1',
#  'rgb_mrcnn_mask_bn1',
#  'flow_mrcnn_mask_bn1',
#  'rgb_roi_align_classifier',
#  'flow_roi_align_classifier',
#  'activation_190',
#  'activation_194',
#  'rgb_mrcnn_class_conv1',
#  'flow_mrcnn_class_conv1',
#  'rgb_mrcnn_mask_conv2',
#  'flow_mrcnn_mask_conv2',
#  'rgb_mrcnn_class_bn1',
#  'flow_mrcnn_class_bn1',
#  'rgb_mrcnn_mask_bn2',
#  'flow_mrcnn_mask_bn2',
#  'activation_185',
#  'activation_186',
#  'activation_191',
#  'activation_195',
#  'dropout_1',
#  'dropout_2',
#  'rgb_mrcnn_mask_conv3',
#  'flow_mrcnn_mask_conv3',
#  'concatenate_2',
#  'rgb_mrcnn_mask_bn3',
#  'flow_mrcnn_mask_bn3',
#  'mrcnn_class_conv2',
#  'activation_192',
#  'activation_196',
#  'mrcnn_class_bn2',
#  'rgb_mrcnn_mask_conv4',
#  'flow_mrcnn_mask_conv4',
#  'activation_187',
#  'rgb_mrcnn_mask_bn4',
#  'flow_mrcnn_mask_bn4',
#  'pool_squeeze',
#  'activation_193',
#  'activation_197',
#  'mrcnn_actor_class_logits',
#  'mrcnn_action_class_logits',
#  'rgb_mrcnn_mask_deconv',
#  'flow_mrcnn_mask_deconv',
#  'input_image_meta',
#  'mrcnn_bbox_fc',
#  'rgb_mrcnn_mask',
#  'flow_mrcnn_mask',
#  'r_mrcnn_actor_class_logits',
#  'lambda_26',
#  'f_mrcnn_actor_class_logits',
#  'r_mrcnn_action_class_logits',
#  'f_mrcnn_action_class_logits',
#  'rgb_rpn_class_logits',
#  'flow_rpn_class_logits',
#  'mrcnn_bbox',
#  'mrcnn_mask',
#  'input_rpn_match',
#  'input_rpn_bbox',
#  'r_actor_class_loss',
#  'f_actor_class_loss',
#  'r_action_class_loss',
#  'f_action_class_loss',
#  'target_bbox',
#  'target_actor_class_ids',
#  'target_mask',
#  'mrcnn_actor_class',
#  'mrcnn_action_class',
#  'r_output_rois',
#  'f_output_rois',
#  'r_rpn_class_loss',
#  'f_rpn_class_loss',
#  'r_rpn_bbox_loss',
#  'f_rpn_bbox_loss',
#  'actor_class_loss',
#  'action_class_loss',
#  'mrcnn_bbox_loss',
#  'mrcnn_mask_loss']

# %%
fn = model.find_last()[1]
print(fn)
import h5py
f = h5py.File(fn, mode='r')
# Out:
# ../outputs/padnet_v1.0/a2d20180206T0225/padnet_a2d_0012.h5

# %%
def load_weights_from_hdf5_group_by_weight_names(f, layers):
    weights_to_be_assigned = [l.weights for l in layers]
    weight_names_to_be_assigned = [w.name for w in weights_to_be_assigned]
    weight_value_tuples = []

# %%
load_weights_from_hdf5_group_by_name(f, [model.rgb_resnet_3d_model], verbose=True, skip_mismatch=True)
# Out:
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((7, 7, 3, 64) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((64,) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 64, 64) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 64, 64) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 64, 256) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 64, 256) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 64) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 128) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((128,) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 128, 128) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 128, 512) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 512) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 512, 128) vs (3, 1, 1, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 128, 128) vs (3, 1, 1, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((128,) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 128, 512) vs (3, 1, 1, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 512, 256) vs (3, 1, 1, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (7, 7, 3, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (64,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (64,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (64,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 512, 1024) vs (1, 1, 64, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (3, 3, 64, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (64,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 64, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (1, 1, 64, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 256, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (3, 3, 64, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 64, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (1, 1, 256, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (64,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (3, 3, 64, 64)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (1, 1, 64, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 256, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (3, 3, 128, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 128, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (1, 1, 256, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 512, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (3, 3, 128, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (1, 1, 512, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (3, 3, 128, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (1, 1, 128, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 512, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (3, 3, 128, 128)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (128,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 128, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (1, 1, 512, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (1, 1, 256, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 512, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 256, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 256, 1024) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 256, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 256) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 256, 256) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 256, 256) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 512) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 512, 512) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 512, 512) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 512, 2048) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 1024, 2048) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (1, 1, 256, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 2048, 512) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1, 1, 2048, 512) vs (256,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (1, 1, 256, 1024)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 3, 512, 512) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((3, 1, 1, 512, 512) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((64,) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((64,) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((64,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((128,) vs (1024,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((128,) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((128,) vs (3, 3, 256, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 1024, 256)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 1024, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (3, 3, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (1, 1, 512, 2048)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((1024,) vs (2048,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 1024, 2048)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (2048,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (1, 1, 2048, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((256,) vs (3, 3, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (1, 1, 512, 2048)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (2048,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (1, 1, 2048, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((2048,) vs (512,)).
#   weight_values[i].shape))
# ../utils/misc.py:110: UserWarning: Skipping loading of weights for layer rgb_resnet_3d due to mismatch in shape ((512,) vs (3, 3, 512, 512)).
#   weight_values[i].shape))
# ../utils/misc.py:131: UserWarning: conv1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: conv1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn_conv1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn_conv1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2c_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn2c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res2c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3a_branch1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3a_branch1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3b_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3b_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3c_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3c_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3d_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3d_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3d_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3d_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn3d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res3d_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch1/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4a_branch1/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch1/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4a_branch1/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4b_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4b_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4b_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4b_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4b_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4b_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4b_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4c_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4c_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4c_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4c_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4c_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4c_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4c_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4c_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4d_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4d_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4d_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4d_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4d_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4d_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4d_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4d_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4d_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4e_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4e_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4e_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4e_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4e_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4e_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4e_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4e_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4e_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4e_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4e_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4e_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4f_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4f_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4f_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4f_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4f_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4f_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4g_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4g_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4g_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4g_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4g_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4g_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4h_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4h_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4h_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4h_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4h_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4h_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4i_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4i_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4i_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4i_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4i_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4i_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4j_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4j_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4j_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4j_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4j_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4j_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tbn4j_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4j_branch2c/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4j_branch2c/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4j_branch2c/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4j_branch2c/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4k_branch2a/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4k_branch2a/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4k_branch2a/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4k_branch2a/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4k_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: res4k_branch2b/bias:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4k_branch2b/gamma:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: bn4k_branch2b/beta:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ../utils/misc.py:131: UserWarning: tres4k_branch2b/kernel:0 is not loaded.
#   warnings.warn('%s is not loaded.' % wil.name)
# ...
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4t_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4t_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4u_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4u_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4u_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4u_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4v_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4v_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4v_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4v_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4v_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tres4v_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4v_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4v_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4v_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'res4w_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#   <HDF5 dataset "kernel:0": shape (1, 1, 1024, 256), type "<f4">),
#  (<tf.Variable 'res4w_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4w_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4w_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'res4w_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4w_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tres4w_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "bias:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4w_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "gamma:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4w_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4w_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "beta:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn2b_branch2c/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn2b_branch2c/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn2c_branch2c/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn2c_branch2c/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4b_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4b_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4b_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4b_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4b_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4c_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4c_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4c_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4c_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4d_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4d_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4d_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4d_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4d_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4e_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4e_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4e_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4e_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4e_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4e_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4e_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'tbn4f_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4g_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4g_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4g_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4g_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4g_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4h_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4h_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4h_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4h_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4i_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4i_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4i_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4i_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4i_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4j_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4j_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4j_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4j_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4j_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4j_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4j_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'tbn4k_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4l_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4l_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4l_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4l_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4l_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4m_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4m_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4m_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4m_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4n_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4n_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4n_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4n_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4n_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4o_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4o_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4o_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4o_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4o_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4o_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4o_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'tbn4p_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4q_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4q_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4q_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4q_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'tbn4q_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4r_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4r_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (256,), type "<f4">),
#  (<tf.Variable 'bn4r_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn4r_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (1024,), type "<f4">),
#  (<tf.Variable 'bn5b_branch2a/moving_mean:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (512,), type "<f4">),
#  (<tf.Variable 'bn5b_branch2a/moving_variance:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (512,), type "<f4">),
#  (<tf.Variable 'bn5b_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (512,), type "<f4">),
#  (<tf.Variable 'tbn5b_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (512,), type "<f4">),
#  (<tf.Variable 'tbn5b_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (512,), type "<f4">),
#  (<tf.Variable 'bn5c_branch2a/moving_mean:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (512,), type "<f4">),
#  (<tf.Variable 'bn5c_branch2a/moving_variance:0' shape=(512,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (512,), type "<f4">),
#  (<tf.Variable 'bn5c_branch2c/moving_mean:0' shape=(2048,) dtype=float32_ref>,
#   <HDF5 dataset "moving_mean:0": shape (2048,), type "<f4">),
#  (<tf.Variable 'bn5c_branch2c/moving_variance:0' shape=(2048,) dtype=float32_ref>,
#   <HDF5 dataset "moving_variance:0": shape (2048,), type "<f4">)]

# %%
f['rgb_resnet_3d'].attrs['weight_names']
# Out:
# array([b'tres4b_branch2b/kernel:0', b'tres4b_branch2b/bias:0',
#        b'tbn4b_branch2b/gamma:0', b'tbn4b_branch2b/beta:0',
#        b'tres4c_branch2b/kernel:0', b'tres4c_branch2b/bias:0',
#        b'tbn4c_branch2b/gamma:0', b'tbn4c_branch2b/beta:0',
#        b'tres4d_branch2b/kernel:0', b'tres4d_branch2b/bias:0',
#        b'tbn4d_branch2b/gamma:0', b'tbn4d_branch2b/beta:0',
#        b'tres4e_branch2b/kernel:0', b'tres4e_branch2b/bias:0',
#        b'tbn4e_branch2b/gamma:0', b'tbn4e_branch2b/beta:0',
#        b'tres4f_branch2b/kernel:0', b'tres4f_branch2b/bias:0',
#        b'tbn4f_branch2b/gamma:0', b'tbn4f_branch2b/beta:0',
#        b'tres4g_branch2b/kernel:0', b'tres4g_branch2b/bias:0',
#        b'tbn4g_branch2b/gamma:0', b'tbn4g_branch2b/beta:0',
#        b'tres4h_branch2b/kernel:0', b'tres4h_branch2b/bias:0',
#        b'tbn4h_branch2b/gamma:0', b'tbn4h_branch2b/beta:0',
#        b'tres4i_branch2b/kernel:0', b'tres4i_branch2b/bias:0',
#        b'tbn4i_branch2b/gamma:0', b'tbn4i_branch2b/beta:0',
#        b'tres4j_branch2b/kernel:0', b'tres4j_branch2b/bias:0',
#        b'tbn4j_branch2b/gamma:0', b'tbn4j_branch2b/beta:0',
#        b'tres4k_branch2b/kernel:0', b'tres4k_branch2b/bias:0',
#        b'tbn4k_branch2b/gamma:0', b'tbn4k_branch2b/beta:0',
#        b'tres4l_branch2b/kernel:0', b'tres4l_branch2b/bias:0',
#        b'tbn4l_branch2b/gamma:0', b'tbn4l_branch2b/beta:0',
#        b'tres4m_branch2b/kernel:0', b'tres4m_branch2b/bias:0',
#        b'tbn4m_branch2b/gamma:0', b'tbn4m_branch2b/beta:0',
#        b'tres4n_branch2b/kernel:0', b'tres4n_branch2b/bias:0',
#        b'tbn4n_branch2b/gamma:0', b'tbn4n_branch2b/beta:0',
#        b'tres4o_branch2b/kernel:0', b'tres4o_branch2b/bias:0',
#        b'tbn4o_branch2b/gamma:0', b'tbn4o_branch2b/beta:0',
#        b'tres4p_branch2b/kernel:0', b'tres4p_branch2b/bias:0',
#        b'tbn4p_branch2b/gamma:0', b'tbn4p_branch2b/beta:0',
#        b'tres4q_branch2b/kernel:0', b'tres4q_branch2b/bias:0',
#        b'tbn4q_branch2b/gamma:0', b'tbn4q_branch2b/beta:0',
#        b'tres4r_branch2b/kernel:0', b'tres4r_branch2b/bias:0',
#        b'tbn4r_branch2b/gamma:0', b'tbn4r_branch2b/beta:0',
#        b'tres4s_branch2b/kernel:0', b'tres4s_branch2b/bias:0',
#        b'tbn4s_branch2b/gamma:0', b'tbn4s_branch2b/beta:0',
#        b'tres4t_branch2b/kernel:0', b'tres4t_branch2b/bias:0',
#        b'tbn4t_branch2b/gamma:0', b'tbn4t_branch2b/beta:0',
#        b'tres4u_branch2b/kernel:0', b'tres4u_branch2b/bias:0',
#        b'tbn4u_branch2b/gamma:0', b'tbn4u_branch2b/beta:0',
#        b'tres4v_branch2b/kernel:0', b'tres4v_branch2b/bias:0',
#        b'tbn4v_branch2b/gamma:0', b'tbn4v_branch2b/beta:0',
#        b'tres4w_branch2b/kernel:0', b'tres4w_branch2b/bias:0',
#        b'tbn4w_branch2b/gamma:0', b'tbn4w_branch2b/beta:0',
#        b'tres5a_branch2b/kernel:0', b'tres5a_branch2b/bias:0',
#        b'tbn5a_branch2b/gamma:0', b'tbn5a_branch2b/beta:0',
#        b'tres5b_branch2b/kernel:0', b'tres5b_branch2b/bias:0',
#        b'tbn5b_branch2b/gamma:0', b'tbn5b_branch2b/beta:0',
#        b'tres5c_branch2b/kernel:0', b'tres5c_branch2b/bias:0',
#        b'tbn5c_branch2b/gamma:0', b'tbn5c_branch2b/beta:0',
#        b'conv1/kernel:0', b'conv1/bias:0', b'bn_conv1/gamma:0',
#        b'bn_conv1/beta:0', b'bn_conv1/moving_mean:0',
#        b'bn_conv1/moving_variance:0', b'res2a_branch2a/kernel:0',
#        b'res2a_branch2a/bias:0', b'bn2a_branch2a/gamma:0',
#        b'bn2a_branch2a/beta:0', b'bn2a_branch2a/moving_mean:0',
#        b'bn2a_branch2a/moving_variance:0', b'res2a_branch2b/kernel:0',
#        b'res2a_branch2b/bias:0', b'bn2a_branch2b/gamma:0',
#        b'bn2a_branch2b/beta:0', b'bn2a_branch2b/moving_mean:0',
#        b'bn2a_branch2b/moving_variance:0', b'res2a_branch2c/kernel:0',
#        b'res2a_branch2c/bias:0', b'res2a_branch1/kernel:0',
#        b'res2a_branch1/bias:0', b'bn2a_branch2c/gamma:0',
#        b'bn2a_branch2c/beta:0', b'bn2a_branch2c/moving_mean:0',
#        b'bn2a_branch2c/moving_variance:0', b'bn2a_branch1/gamma:0',
#        b'bn2a_branch1/beta:0', b'bn2a_branch1/moving_mean:0',
#        b'bn2a_branch1/moving_variance:0', b'res2b_branch2a/kernel:0',
#        b'res2b_branch2a/bias:0', b'bn2b_branch2a/gamma:0',
#        b'bn2b_branch2a/beta:0', b'bn2b_branch2a/moving_mean:0',
#        b'bn2b_branch2a/moving_variance:0', b'res2b_branch2b/kernel:0',
#        b'res2b_branch2b/bias:0', b'bn2b_branch2b/gamma:0',
#        b'bn2b_branch2b/beta:0', b'bn2b_branch2b/moving_mean:0',
#        b'bn2b_branch2b/moving_variance:0', b'res2b_branch2c/kernel:0',
#        b'res2b_branch2c/bias:0', b'bn2b_branch2c/gamma:0',
#        b'bn2b_branch2c/beta:0', b'bn2b_branch2c/moving_mean:0',
#        b'bn2b_branch2c/moving_variance:0', b'res2c_branch2a/kernel:0',
#        b'res2c_branch2a/bias:0', b'bn2c_branch2a/gamma:0',
#        b'bn2c_branch2a/beta:0', b'bn2c_branch2a/moving_mean:0',
#        b'bn2c_branch2a/moving_variance:0', b'res2c_branch2b/kernel:0',
#        b'res2c_branch2b/bias:0', b'bn2c_branch2b/gamma:0',
#        b'bn2c_branch2b/beta:0', b'bn2c_branch2b/moving_mean:0',
#        b'bn2c_branch2b/moving_variance:0', b'res2c_branch2c/kernel:0',
#        b'res2c_branch2c/bias:0', b'bn2c_branch2c/gamma:0',
#        b'bn2c_branch2c/beta:0', b'bn2c_branch2c/moving_mean:0',
#        b'bn2c_branch2c/moving_variance:0', b'res3a_branch2a/kernel:0',
#        b'res3a_branch2a/bias:0', b'bn3a_branch2a/gamma:0',
#        b'bn3a_branch2a/beta:0', b'bn3a_branch2a/moving_mean:0',
#        b'bn3a_branch2a/moving_variance:0', b'res3a_branch2b/kernel:0',
#        b'res3a_branch2b/bias:0', b'bn3a_branch2b/gamma:0',
#        b'bn3a_branch2b/beta:0', b'bn3a_branch2b/moving_mean:0',
#        b'bn3a_branch2b/moving_variance:0', b'res3a_branch2c/kernel:0',
#        b'res3a_branch2c/bias:0', b'res3a_branch1/kernel:0',
#        b'res3a_branch1/bias:0', b'bn3a_branch2c/gamma:0',
#        b'bn3a_branch2c/beta:0', b'bn3a_branch2c/moving_mean:0',
#        b'bn3a_branch2c/moving_variance:0', b'bn3a_branch1/gamma:0',
#        b'bn3a_branch1/beta:0', b'bn3a_branch1/moving_mean:0',
#        b'bn3a_branch1/moving_variance:0', b'res3b_branch2a/kernel:0',
#        b'res3b_branch2a/bias:0', b'bn3b_branch2a/gamma:0',
#        b'bn3b_branch2a/beta:0', b'bn3b_branch2a/moving_mean:0',
#        b'bn3b_branch2a/moving_variance:0', b'res3b_branch2b/kernel:0',
#        b'res3b_branch2b/bias:0', b'bn3b_branch2b/gamma:0',
#        b'bn3b_branch2b/beta:0', b'bn3b_branch2b/moving_mean:0',
#        b'bn3b_branch2b/moving_variance:0', b'res3b_branch2c/kernel:0',
#        b'res3b_branch2c/bias:0', b'bn3b_branch2c/gamma:0',
#        b'bn3b_branch2c/beta:0', b'bn3b_branch2c/moving_mean:0',
#        b'bn3b_branch2c/moving_variance:0', b'res3c_branch2a/kernel:0',
#        b'res3c_branch2a/bias:0', b'bn3c_branch2a/gamma:0',
#        b'bn3c_branch2a/beta:0', b'bn3c_branch2a/moving_mean:0',
#        b'bn3c_branch2a/moving_variance:0', b'res3c_branch2b/kernel:0',
#        b'res3c_branch2b/bias:0', b'bn3c_branch2b/gamma:0',
#        b'bn3c_branch2b/beta:0', b'bn3c_branch2b/moving_mean:0',
#        b'bn3c_branch2b/moving_variance:0', b'res3c_branch2c/kernel:0',
#        b'res3c_branch2c/bias:0', b'bn3c_branch2c/gamma:0',
#        b'bn3c_branch2c/beta:0', b'bn3c_branch2c/moving_mean:0',
#        b'bn3c_branch2c/moving_variance:0', b'res3d_branch2a/kernel:0',
#        b'res3d_branch2a/bias:0', b'bn3d_branch2a/gamma:0',
#        b'bn3d_branch2a/beta:0', b'bn3d_branch2a/moving_mean:0',
#        b'bn3d_branch2a/moving_variance:0', b'res3d_branch2b/kernel:0',
#        b'res3d_branch2b/bias:0', b'bn3d_branch2b/gamma:0',
#        b'bn3d_branch2b/beta:0', b'bn3d_branch2b/moving_mean:0',
#        b'bn3d_branch2b/moving_variance:0', b'res3d_branch2c/kernel:0',
#        b'res3d_branch2c/bias:0', b'bn3d_branch2c/gamma:0',
#        b'bn3d_branch2c/beta:0', b'bn3d_branch2c/moving_mean:0',
#        b'bn3d_branch2c/moving_variance:0', b'res4a_branch2a/kernel:0',
#        b'res4a_branch2a/bias:0', b'bn4a_branch2a/gamma:0',
#        b'bn4a_branch2a/beta:0', b'bn4a_branch2a/moving_mean:0',
#        b'bn4a_branch2a/moving_variance:0', b'res4a_branch2b/kernel:0',
#        b'res4a_branch2b/bias:0', b'bn4a_branch2b/gamma:0',
#        b'bn4a_branch2b/beta:0', b'bn4a_branch2b/moving_mean:0',
#        b'bn4a_branch2b/moving_variance:0', b'res4a_branch2c/kernel:0',
#        b'res4a_branch2c/bias:0', b'res4a_branch1/kernel:0',
#        b'res4a_branch1/bias:0', b'bn4a_branch2c/gamma:0',
#        b'bn4a_branch2c/beta:0', b'bn4a_branch2c/moving_mean:0',
#        b'bn4a_branch2c/moving_variance:0', b'bn4a_branch1/gamma:0',
#        b'bn4a_branch1/beta:0', b'bn4a_branch1/moving_mean:0',
#        b'bn4a_branch1/moving_variance:0', b'res4b_branch2a/kernel:0',
#        b'res4b_branch2a/bias:0', b'bn4b_branch2a/gamma:0',
#        b'bn4b_branch2a/beta:0', b'bn4b_branch2a/moving_mean:0',
#        b'bn4b_branch2a/moving_variance:0', b'res4b_branch2b/kernel:0',
#        b'res4b_branch2b/bias:0', b'bn4b_branch2b/gamma:0',
#        b'bn4b_branch2b/beta:0', b'bn4b_branch2b/moving_mean:0',
#        b'bn4b_branch2b/moving_variance:0',
#        b'tbn4b_branch2b/moving_mean:0',
#        b'tbn4b_branch2b/moving_variance:0', b'res4b_branch2c/kernel:0',
#        b'res4b_branch2c/bias:0', b'bn4b_branch2c/gamma:0',
#        b'bn4b_branch2c/beta:0', b'bn4b_branch2c/moving_mean:0',
#        b'bn4b_branch2c/moving_variance:0', b'res4c_branch2a/kernel:0',
#        b'res4c_branch2a/bias:0', b'bn4c_branch2a/gamma:0',
#        b'bn4c_branch2a/beta:0', b'bn4c_branch2a/moving_mean:0',
#        b'bn4c_branch2a/moving_variance:0', b'res4c_branch2b/kernel:0',
#        b'res4c_branch2b/bias:0', b'bn4c_branch2b/gamma:0',
#        b'bn4c_branch2b/beta:0', b'bn4c_branch2b/moving_mean:0',
#        b'bn4c_branch2b/moving_variance:0',
#        b'tbn4c_branch2b/moving_mean:0',
#        b'tbn4c_branch2b/moving_variance:0', b'res4c_branch2c/kernel:0',
#        b'res4c_branch2c/bias:0', b'bn4c_branch2c/gamma:0',
#        b'bn4c_branch2c/beta:0', b'bn4c_branch2c/moving_mean:0',
#        b'bn4c_branch2c/moving_variance:0', b'res4d_branch2a/kernel:0',
#        b'res4d_branch2a/bias:0', b'bn4d_branch2a/gamma:0',
#        b'bn4d_branch2a/beta:0', b'bn4d_branch2a/moving_mean:0',
#        b'bn4d_branch2a/moving_variance:0', b'res4d_branch2b/kernel:0',
#        b'res4d_branch2b/bias:0', b'bn4d_branch2b/gamma:0',
#        b'bn4d_branch2b/beta:0', b'bn4d_branch2b/moving_mean:0',
#        b'bn4d_branch2b/moving_variance:0',
#        b'tbn4d_branch2b/moving_mean:0',
#        b'tbn4d_branch2b/moving_variance:0', b'res4d_branch2c/kernel:0',
#        b'res4d_branch2c/bias:0', b'bn4d_branch2c/gamma:0',
#        b'bn4d_branch2c/beta:0', b'bn4d_branch2c/moving_mean:0',
#        b'bn4d_branch2c/moving_variance:0', b'res4e_branch2a/kernel:0',
#        b'res4e_branch2a/bias:0', b'bn4e_branch2a/gamma:0',
#        b'bn4e_branch2a/beta:0', b'bn4e_branch2a/moving_mean:0',
#        b'bn4e_branch2a/moving_variance:0', b'res4e_branch2b/kernel:0',
#        b'res4e_branch2b/bias:0', b'bn4e_branch2b/gamma:0',
#        b'bn4e_branch2b/beta:0', b'bn4e_branch2b/moving_mean:0',
#        b'bn4e_branch2b/moving_variance:0',
#        b'tbn4e_branch2b/moving_mean:0',
#        b'tbn4e_branch2b/moving_variance:0', b'res4e_branch2c/kernel:0',
#        b'res4e_branch2c/bias:0', b'bn4e_branch2c/gamma:0',
#        b'bn4e_branch2c/beta:0', b'bn4e_branch2c/moving_mean:0',
#        b'bn4e_branch2c/moving_variance:0', b'res4f_branch2a/kernel:0',
#        b'res4f_branch2a/bias:0', b'bn4f_branch2a/gamma:0',
#        b'bn4f_branch2a/beta:0', b'bn4f_branch2a/moving_mean:0',
#        b'bn4f_branch2a/moving_variance:0', b'res4f_branch2b/kernel:0',
#        b'res4f_branch2b/bias:0', b'bn4f_branch2b/gamma:0',
#        b'bn4f_branch2b/beta:0', b'bn4f_branch2b/moving_mean:0',
#        b'bn4f_branch2b/moving_variance:0',
#        b'tbn4f_branch2b/moving_mean:0',
#        b'tbn4f_branch2b/moving_variance:0', b'res4f_branch2c/kernel:0',
#        b'res4f_branch2c/bias:0', b'bn4f_branch2c/gamma:0',
#        b'bn4f_branch2c/beta:0', b'bn4f_branch2c/moving_mean:0',
#        b'bn4f_branch2c/moving_variance:0', b'res4g_branch2a/kernel:0',
#        b'res4g_branch2a/bias:0', b'bn4g_branch2a/gamma:0',
#        b'bn4g_branch2a/beta:0', b'bn4g_branch2a/moving_mean:0',
#        b'bn4g_branch2a/moving_variance:0', b'res4g_branch2b/kernel:0',
#        b'res4g_branch2b/bias:0', b'bn4g_branch2b/gamma:0',
#        b'bn4g_branch2b/beta:0', b'bn4g_branch2b/moving_mean:0',
#        b'bn4g_branch2b/moving_variance:0',
#        b'tbn4g_branch2b/moving_mean:0',
#        b'tbn4g_branch2b/moving_variance:0', b'res4g_branch2c/kernel:0',
#        b'res4g_branch2c/bias:0', b'bn4g_branch2c/gamma:0',
#        b'bn4g_branch2c/beta:0', b'bn4g_branch2c/moving_mean:0',
#        b'bn4g_branch2c/moving_variance:0', b'res4h_branch2a/kernel:0',
#        b'res4h_branch2a/bias:0', b'bn4h_branch2a/gamma:0',
#        b'bn4h_branch2a/beta:0', b'bn4h_branch2a/moving_mean:0',
#        b'bn4h_branch2a/moving_variance:0', b'res4h_branch2b/kernel:0',
#        b'res4h_branch2b/bias:0', b'bn4h_branch2b/gamma:0',
#        b'bn4h_branch2b/beta:0', b'bn4h_branch2b/moving_mean:0',
#        b'bn4h_branch2b/moving_variance:0',
#        b'tbn4h_branch2b/moving_mean:0',
#        b'tbn4h_branch2b/moving_variance:0', b'res4h_branch2c/kernel:0',
#        b'res4h_branch2c/bias:0', b'bn4h_branch2c/gamma:0',
#        b'bn4h_branch2c/beta:0', b'bn4h_branch2c/moving_mean:0',
#        b'bn4h_branch2c/moving_variance:0', b'res4i_branch2a/kernel:0',
#        b'res4i_branch2a/bias:0', b'bn4i_branch2a/gamma:0',
#        b'bn4i_branch2a/beta:0', b'bn4i_branch2a/moving_mean:0',
#        b'bn4i_branch2a/moving_variance:0', b'res4i_branch2b/kernel:0',
#        b'res4i_branch2b/bias:0', b'bn4i_branch2b/gamma:0',
#        b'bn4i_branch2b/beta:0', b'bn4i_branch2b/moving_mean:0',
#        b'bn4i_branch2b/moving_variance:0',
#        b'tbn4i_branch2b/moving_mean:0',
#        b'tbn4i_branch2b/moving_variance:0', b'res4i_branch2c/kernel:0',
#        b'res4i_branch2c/bias:0', b'bn4i_branch2c/gamma:0',
#        b'bn4i_branch2c/beta:0', b'bn4i_branch2c/moving_mean:0',
#        b'bn4i_branch2c/moving_variance:0', b'res4j_branch2a/kernel:0',
#        b'res4j_branch2a/bias:0', b'bn4j_branch2a/gamma:0',
#        b'bn4j_branch2a/beta:0', b'bn4j_branch2a/moving_mean:0',
#        b'bn4j_branch2a/moving_variance:0', b'res4j_branch2b/kernel:0',
#        b'res4j_branch2b/bias:0', b'bn4j_branch2b/gamma:0',
#        b'bn4j_branch2b/beta:0', b'bn4j_branch2b/moving_mean:0',
#        b'bn4j_branch2b/moving_variance:0',
#        b'tbn4j_branch2b/moving_mean:0',
#        b'tbn4j_branch2b/moving_variance:0', b'res4j_branch2c/kernel:0',
#        b'res4j_branch2c/bias:0', b'bn4j_branch2c/gamma:0',
#        b'bn4j_branch2c/beta:0', b'bn4j_branch2c/moving_mean:0',
#        b'bn4j_branch2c/moving_variance:0', b'res4k_branch2a/kernel:0',
#        b'res4k_branch2a/bias:0', b'bn4k_branch2a/gamma:0',
#        b'bn4k_branch2a/beta:0', b'bn4k_branch2a/moving_mean:0',
#        b'bn4k_branch2a/moving_variance:0', b'res4k_branch2b/kernel:0',
#        b'res4k_branch2b/bias:0', b'bn4k_branch2b/gamma:0',
#        b'bn4k_branch2b/beta:0', b'bn4k_branch2b/moving_mean:0',
#        b'bn4k_branch2b/moving_variance:0',
#        b'tbn4k_branch2b/moving_mean:0',
#        b'tbn4k_branch2b/moving_variance:0', b'res4k_branch2c/kernel:0',
#        b'res4k_branch2c/bias:0', b'bn4k_branch2c/gamma:0',
#        b'bn4k_branch2c/beta:0', b'bn4k_branch2c/moving_mean:0',
#        b'bn4k_branch2c/moving_variance:0', b'res4l_branch2a/kernel:0',
#        b'res4l_branch2a/bias:0', b'bn4l_branch2a/gamma:0',
#        b'bn4l_branch2a/beta:0', b'bn4l_branch2a/moving_mean:0',
#        b'bn4l_branch2a/moving_variance:0', b'res4l_branch2b/kernel:0',
#        b'res4l_branch2b/bias:0', b'bn4l_branch2b/gamma:0',
#        b'bn4l_branch2b/beta:0', b'bn4l_branch2b/moving_mean:0',
#        b'bn4l_branch2b/moving_variance:0',
#        b'tbn4l_branch2b/moving_mean:0',
#        b'tbn4l_branch2b/moving_variance:0', b'res4l_branch2c/kernel:0',
#        b'res4l_branch2c/bias:0', b'bn4l_branch2c/gamma:0',
#        b'bn4l_branch2c/beta:0', b'bn4l_branch2c/moving_mean:0',
#        b'bn4l_branch2c/moving_variance:0', b'res4m_branch2a/kernel:0',
#        b'res4m_branch2a/bias:0', b'bn4m_branch2a/gamma:0',
#        b'bn4m_branch2a/beta:0', b'bn4m_branch2a/moving_mean:0',
#        b'bn4m_branch2a/moving_variance:0', b'res4m_branch2b/kernel:0',
#        b'res4m_branch2b/bias:0', b'bn4m_branch2b/gamma:0',
#        b'bn4m_branch2b/beta:0', b'bn4m_branch2b/moving_mean:0',
#        b'bn4m_branch2b/moving_variance:0',
#        b'tbn4m_branch2b/moving_mean:0',
#        b'tbn4m_branch2b/moving_variance:0', b'res4m_branch2c/kernel:0',
#        b'res4m_branch2c/bias:0', b'bn4m_branch2c/gamma:0',
#        b'bn4m_branch2c/beta:0', b'bn4m_branch2c/moving_mean:0',
#        b'bn4m_branch2c/moving_variance:0', b'res4n_branch2a/kernel:0',
#        b'res4n_branch2a/bias:0', b'bn4n_branch2a/gamma:0',
#        b'bn4n_branch2a/beta:0', b'bn4n_branch2a/moving_mean:0',
#        b'bn4n_branch2a/moving_variance:0', b'res4n_branch2b/kernel:0',
#        b'res4n_branch2b/bias:0', b'bn4n_branch2b/gamma:0',
#        b'bn4n_branch2b/beta:0', b'bn4n_branch2b/moving_mean:0',
#        b'bn4n_branch2b/moving_variance:0',
#        b'tbn4n_branch2b/moving_mean:0',
#        b'tbn4n_branch2b/moving_variance:0', b'res4n_branch2c/kernel:0',
#        b'res4n_branch2c/bias:0', b'bn4n_branch2c/gamma:0',
#        b'bn4n_branch2c/beta:0', b'bn4n_branch2c/moving_mean:0',
#        b'bn4n_branch2c/moving_variance:0', b'res4o_branch2a/kernel:0',
#        b'res4o_branch2a/bias:0', b'bn4o_branch2a/gamma:0',
#        b'bn4o_branch2a/beta:0', b'bn4o_branch2a/moving_mean:0',
#        b'bn4o_branch2a/moving_variance:0', b'res4o_branch2b/kernel:0',
#        b'res4o_branch2b/bias:0', b'bn4o_branch2b/gamma:0',
#        b'bn4o_branch2b/beta:0', b'bn4o_branch2b/moving_mean:0',
#        b'bn4o_branch2b/moving_variance:0',
#        b'tbn4o_branch2b/moving_mean:0',
#        b'tbn4o_branch2b/moving_variance:0', b'res4o_branch2c/kernel:0',
#        b'res4o_branch2c/bias:0', b'bn4o_branch2c/gamma:0',
#        b'bn4o_branch2c/beta:0', b'bn4o_branch2c/moving_mean:0',
#        b'bn4o_branch2c/moving_variance:0', b'res4p_branch2a/kernel:0',
#        b'res4p_branch2a/bias:0', b'bn4p_branch2a/gamma:0',
#        b'bn4p_branch2a/beta:0', b'bn4p_branch2a/moving_mean:0',
#        b'bn4p_branch2a/moving_variance:0', b'res4p_branch2b/kernel:0',
#        b'res4p_branch2b/bias:0', b'bn4p_branch2b/gamma:0',
#        b'bn4p_branch2b/beta:0', b'bn4p_branch2b/moving_mean:0',
#        b'bn4p_branch2b/moving_variance:0',
#        b'tbn4p_branch2b/moving_mean:0',
#        b'tbn4p_branch2b/moving_variance:0', b'res4p_branch2c/kernel:0',
#        b'res4p_branch2c/bias:0', b'bn4p_branch2c/gamma:0',
#        b'bn4p_branch2c/beta:0', b'bn4p_branch2c/moving_mean:0',
#        b'bn4p_branch2c/moving_variance:0', b'res4q_branch2a/kernel:0',
#        b'res4q_branch2a/bias:0', b'bn4q_branch2a/gamma:0',
#        b'bn4q_branch2a/beta:0', b'bn4q_branch2a/moving_mean:0',
#        b'bn4q_branch2a/moving_variance:0', b'res4q_branch2b/kernel:0',
#        b'res4q_branch2b/bias:0', b'bn4q_branch2b/gamma:0',
#        b'bn4q_branch2b/beta:0', b'bn4q_branch2b/moving_mean:0',
#        b'bn4q_branch2b/moving_variance:0',
#        b'tbn4q_branch2b/moving_mean:0',
#        b'tbn4q_branch2b/moving_variance:0', b'res4q_branch2c/kernel:0',
#        b'res4q_branch2c/bias:0', b'bn4q_branch2c/gamma:0',
#        b'bn4q_branch2c/beta:0', b'bn4q_branch2c/moving_mean:0',
#        b'bn4q_branch2c/moving_variance:0', b'res4r_branch2a/kernel:0',
#        b'res4r_branch2a/bias:0', b'bn4r_branch2a/gamma:0',
#        b'bn4r_branch2a/beta:0', b'bn4r_branch2a/moving_mean:0',
#        b'bn4r_branch2a/moving_variance:0', b'res4r_branch2b/kernel:0',
#        b'res4r_branch2b/bias:0', b'bn4r_branch2b/gamma:0',
#        b'bn4r_branch2b/beta:0', b'bn4r_branch2b/moving_mean:0',
#        b'bn4r_branch2b/moving_variance:0',
#        b'tbn4r_branch2b/moving_mean:0',
#        b'tbn4r_branch2b/moving_variance:0', b'res4r_branch2c/kernel:0',
#        b'res4r_branch2c/bias:0', b'bn4r_branch2c/gamma:0',
#        b'bn4r_branch2c/beta:0', b'bn4r_branch2c/moving_mean:0',
#        b'bn4r_branch2c/moving_variance:0', b'res4s_branch2a/kernel:0',
#        b'res4s_branch2a/bias:0', b'bn4s_branch2a/gamma:0',
#        b'bn4s_branch2a/beta:0', b'bn4s_branch2a/moving_mean:0',
#        b'bn4s_branch2a/moving_variance:0', b'res4s_branch2b/kernel:0',
#        b'res4s_branch2b/bias:0', b'bn4s_branch2b/gamma:0',
#        b'bn4s_branch2b/beta:0', b'bn4s_branch2b/moving_mean:0',
#        b'bn4s_branch2b/moving_variance:0',
#        b'tbn4s_branch2b/moving_mean:0',
#        b'tbn4s_branch2b/moving_variance:0', b'res4s_branch2c/kernel:0',
#        b'res4s_branch2c/bias:0', b'bn4s_branch2c/gamma:0',
#        b'bn4s_branch2c/beta:0', b'bn4s_branch2c/moving_mean:0',
#        b'bn4s_branch2c/moving_variance:0', b'res4t_branch2a/kernel:0',
#        b'res4t_branch2a/bias:0', b'bn4t_branch2a/gamma:0',
#        b'bn4t_branch2a/beta:0', b'bn4t_branch2a/moving_mean:0',
#        b'bn4t_branch2a/moving_variance:0', b'res4t_branch2b/kernel:0',
#        b'res4t_branch2b/bias:0', b'bn4t_branch2b/gamma:0',
#        b'bn4t_branch2b/beta:0', b'bn4t_branch2b/moving_mean:0',
#        b'bn4t_branch2b/moving_variance:0',
#        b'tbn4t_branch2b/moving_mean:0',
#        b'tbn4t_branch2b/moving_variance:0', b'res4t_branch2c/kernel:0',
#        b'res4t_branch2c/bias:0', b'bn4t_branch2c/gamma:0',
#        b'bn4t_branch2c/beta:0', b'bn4t_branch2c/moving_mean:0',
#        b'bn4t_branch2c/moving_variance:0', b'res4u_branch2a/kernel:0',
#        b'res4u_branch2a/bias:0', b'bn4u_branch2a/gamma:0',
#        b'bn4u_branch2a/beta:0', b'bn4u_branch2a/moving_mean:0',
#        b'bn4u_branch2a/moving_variance:0', b'res4u_branch2b/kernel:0',
#        b'res4u_branch2b/bias:0', b'bn4u_branch2b/gamma:0',
#        b'bn4u_branch2b/beta:0', b'bn4u_branch2b/moving_mean:0',
#        b'bn4u_branch2b/moving_variance:0',
#        b'tbn4u_branch2b/moving_mean:0',
#        b'tbn4u_branch2b/moving_variance:0', b'res4u_branch2c/kernel:0',
#        b'res4u_branch2c/bias:0', b'bn4u_branch2c/gamma:0',
#        b'bn4u_branch2c/beta:0', b'bn4u_branch2c/moving_mean:0',
#        b'bn4u_branch2c/moving_variance:0', b'res4v_branch2a/kernel:0',
#        b'res4v_branch2a/bias:0', b'bn4v_branch2a/gamma:0',
#        b'bn4v_branch2a/beta:0', b'bn4v_branch2a/moving_mean:0',
#        b'bn4v_branch2a/moving_variance:0', b'res4v_branch2b/kernel:0',
#        b'res4v_branch2b/bias:0', b'bn4v_branch2b/gamma:0',
#        b'bn4v_branch2b/beta:0', b'bn4v_branch2b/moving_mean:0',
#        b'bn4v_branch2b/moving_variance:0',
#        b'tbn4v_branch2b/moving_mean:0',
#        b'tbn4v_branch2b/moving_variance:0', b'res4v_branch2c/kernel:0',
#        b'res4v_branch2c/bias:0', b'bn4v_branch2c/gamma:0',
#        b'bn4v_branch2c/beta:0', b'bn4v_branch2c/moving_mean:0',
#        b'bn4v_branch2c/moving_variance:0', b'res4w_branch2a/kernel:0',
#        b'res4w_branch2a/bias:0', b'bn4w_branch2a/gamma:0',
#        b'bn4w_branch2a/beta:0', b'bn4w_branch2a/moving_mean:0',
#        b'bn4w_branch2a/moving_variance:0', b'res4w_branch2b/kernel:0',
#        b'res4w_branch2b/bias:0', b'bn4w_branch2b/gamma:0',
#        b'bn4w_branch2b/beta:0', b'bn4w_branch2b/moving_mean:0',
#        b'bn4w_branch2b/moving_variance:0',
#        b'tbn4w_branch2b/moving_mean:0',
#        b'tbn4w_branch2b/moving_variance:0', b'res4w_branch2c/kernel:0',
#        b'res4w_branch2c/bias:0', b'bn4w_branch2c/gamma:0',
#        b'bn4w_branch2c/beta:0', b'bn4w_branch2c/moving_mean:0',
#        b'bn4w_branch2c/moving_variance:0', b'res5a_branch2a/kernel:0',
#        b'res5a_branch2a/bias:0', b'bn5a_branch2a/gamma:0',
#        b'bn5a_branch2a/beta:0', b'bn5a_branch2a/moving_mean:0',
#        b'bn5a_branch2a/moving_variance:0', b'res5a_branch2b/kernel:0',
#        b'res5a_branch2b/bias:0', b'bn5a_branch2b/gamma:0',
#        b'bn5a_branch2b/beta:0', b'bn5a_branch2b/moving_mean:0',
#        b'bn5a_branch2b/moving_variance:0',
#        b'tbn5a_branch2b/moving_mean:0',
#        b'tbn5a_branch2b/moving_variance:0', b'res5a_branch2c/kernel:0',
#        b'res5a_branch2c/bias:0', b'res5a_branch1/kernel:0',
#        b'res5a_branch1/bias:0', b'bn5a_branch2c/gamma:0',
#        b'bn5a_branch2c/beta:0', b'bn5a_branch2c/moving_mean:0',
#        b'bn5a_branch2c/moving_variance:0', b'bn5a_branch1/gamma:0',
#        b'bn5a_branch1/beta:0', b'bn5a_branch1/moving_mean:0',
#        b'bn5a_branch1/moving_variance:0', b'res5b_branch2a/kernel:0',
#        b'res5b_branch2a/bias:0', b'bn5b_branch2a/gamma:0',
#        b'bn5b_branch2a/beta:0', b'bn5b_branch2a/moving_mean:0',
#        b'bn5b_branch2a/moving_variance:0', b'res5b_branch2b/kernel:0',
#        b'res5b_branch2b/bias:0', b'bn5b_branch2b/gamma:0',
#        b'bn5b_branch2b/beta:0', b'bn5b_branch2b/moving_mean:0',
#        b'bn5b_branch2b/moving_variance:0',
#        b'tbn5b_branch2b/moving_mean:0',
#        b'tbn5b_branch2b/moving_variance:0', b'res5b_branch2c/kernel:0',
#        b'res5b_branch2c/bias:0', b'bn5b_branch2c/gamma:0',
#        b'bn5b_branch2c/beta:0', b'bn5b_branch2c/moving_mean:0',
#        b'bn5b_branch2c/moving_variance:0', b'res5c_branch2a/kernel:0',
#        b'res5c_branch2a/bias:0', b'bn5c_branch2a/gamma:0',
#        b'bn5c_branch2a/beta:0', b'bn5c_branch2a/moving_mean:0',
#        b'bn5c_branch2a/moving_variance:0', b'res5c_branch2b/kernel:0',
#        b'res5c_branch2b/bias:0', b'bn5c_branch2b/gamma:0',
#        b'bn5c_branch2b/beta:0', b'bn5c_branch2b/moving_mean:0',
#        b'bn5c_branch2b/moving_variance:0',
#        b'tbn5c_branch2b/moving_mean:0',
#        b'tbn5c_branch2b/moving_variance:0', b'res5c_branch2c/kernel:0',
#        b'res5c_branch2c/bias:0', b'bn5c_branch2c/gamma:0',
#        b'bn5c_branch2c/beta:0', b'bn5c_branch2c/moving_mean:0',
#        b'bn5c_branch2c/moving_variance:0'], dtype='|S32')

# %%
model.rgb_resnet_3d_model.weights
# Out:
# [<tf.Variable 'conv1/kernel:0' shape=(7, 7, 3, 64) dtype=float32_ref>,
#  <tf.Variable 'conv1/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn_conv1/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn_conv1/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2a/kernel:0' shape=(1, 1, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2a/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2a/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2a/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2b/kernel:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2b/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2b/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2b/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2c/kernel:0' shape=(1, 1, 64, 256) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch2c/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch1/kernel:0' shape=(1, 1, 64, 256) dtype=float32_ref>,
#  <tf.Variable 'res2a_branch1/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2c/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2c/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch1/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch1/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2a/kernel:0' shape=(1, 1, 256, 64) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2a/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2a/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2a/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2b/kernel:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2b/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2b/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2b/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2c/kernel:0' shape=(1, 1, 64, 256) dtype=float32_ref>,
#  <tf.Variable 'res2b_branch2c/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2c/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2c/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2a/kernel:0' shape=(1, 1, 256, 64) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2a/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2a/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2a/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2b/kernel:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2b/bias:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2b/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2b/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2c/kernel:0' shape=(1, 1, 64, 256) dtype=float32_ref>,
#  <tf.Variable 'res2c_branch2c/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2c/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2c/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2a/kernel:0' shape=(1, 1, 256, 128) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2a/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2a/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2a/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2b/kernel:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2b/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2b/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2b/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2c/kernel:0' shape=(1, 1, 128, 512) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch2c/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch1/kernel:0' shape=(1, 1, 256, 512) dtype=float32_ref>,
#  <tf.Variable 'res3a_branch1/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2c/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2c/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch1/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch1/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2a/kernel:0' shape=(1, 1, 512, 128) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2a/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2a/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2a/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2b/kernel:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2b/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2b/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2b/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2c/kernel:0' shape=(1, 1, 128, 512) dtype=float32_ref>,
#  <tf.Variable 'res3b_branch2c/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2c/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2c/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2a/kernel:0' shape=(1, 1, 512, 128) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2a/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2a/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2a/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2b/kernel:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2b/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2b/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2b/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2c/kernel:0' shape=(1, 1, 128, 512) dtype=float32_ref>,
#  <tf.Variable 'res3c_branch2c/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2c/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2c/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2a/kernel:0' shape=(1, 1, 512, 128) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2a/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2a/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2a/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2b/kernel:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2b/bias:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2b/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2b/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2c/kernel:0' shape=(1, 1, 128, 512) dtype=float32_ref>,
#  <tf.Variable 'res3d_branch2c/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2c/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2c/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2a/kernel:0' shape=(1, 1, 512, 256) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch1/kernel:0' shape=(1, 1, 512, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4a_branch1/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch1/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch1/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4b_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4b_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4b_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4b_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4b_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4c_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4c_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4c_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4c_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4c_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4d_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4d_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4d_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4d_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4d_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4e_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4e_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4e_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4e_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4e_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4f_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4f_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4f_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4f_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4f_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4g_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4g_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4g_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4g_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4g_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4h_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4h_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4h_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4h_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4h_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4i_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4i_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4i_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4i_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4i_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4j_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4j_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4j_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4j_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4j_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4k_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4k_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4k_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4k_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4k_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4l_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4l_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4l_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4l_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4l_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4m_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4m_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4m_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4m_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4m_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4n_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4n_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4n_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4n_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4n_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4o_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4o_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4o_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4o_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4o_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4p_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4p_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4p_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4p_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4p_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4q_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4q_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4q_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4q_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4q_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4r_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4r_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4r_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4r_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4r_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4s_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4s_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4s_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4s_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4s_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4t_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4t_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4t_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4t_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4t_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4u_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4u_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4u_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4u_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4u_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4v_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4v_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4v_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4v_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4v_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2a/kernel:0' shape=(1, 1, 1024, 256) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2a/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2a/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2a/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2b/kernel:0' shape=(3, 3, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tres4w_branch2b/kernel:0' shape=(3, 1, 1, 256, 256) dtype=float32_ref>,
#  <tf.Variable 'tres4w_branch2b/bias:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4w_branch2b/gamma:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4w_branch2b/beta:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2c/kernel:0' shape=(1, 1, 256, 1024) dtype=float32_ref>,
#  <tf.Variable 'res4w_branch2c/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2c/gamma:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2c/beta:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2a/kernel:0' shape=(1, 1, 1024, 512) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2a/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2a/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2a/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2b/kernel:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tres5a_branch2b/kernel:0' shape=(3, 1, 1, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'tres5a_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5a_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5a_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2c/kernel:0' shape=(1, 1, 512, 2048) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch2c/bias:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch1/kernel:0' shape=(1, 1, 1024, 2048) dtype=float32_ref>,
#  <tf.Variable 'res5a_branch1/bias:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2c/gamma:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2c/beta:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch1/gamma:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch1/beta:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2a/kernel:0' shape=(1, 1, 2048, 512) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2a/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2a/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2a/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2b/kernel:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tres5b_branch2b/kernel:0' shape=(3, 1, 1, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'tres5b_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5b_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5b_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2c/kernel:0' shape=(1, 1, 512, 2048) dtype=float32_ref>,
#  <tf.Variable 'res5b_branch2c/bias:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2c/gamma:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2c/beta:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2a/kernel:0' shape=(1, 1, 2048, 512) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2a/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2a/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2a/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2b/kernel:0' shape=(3, 3, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tres5c_branch2b/kernel:0' shape=(3, 1, 1, 512, 512) dtype=float32_ref>,
#  <tf.Variable 'tres5c_branch2b/bias:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5c_branch2b/gamma:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5c_branch2b/beta:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2c/kernel:0' shape=(1, 1, 512, 2048) dtype=float32_ref>,
#  <tf.Variable 'res5c_branch2c/bias:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2c/gamma:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2c/beta:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn_conv1/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn_conv1/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2a/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2a/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2b/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2b/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2c/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch2c/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch1/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2a_branch1/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2a/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2a/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2b/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2b/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2c/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2b_branch2c/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2a/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2a/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2b/moving_mean:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2b/moving_variance:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2c/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn2c_branch2c/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2a/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2a/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2b/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2b/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2c/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch2c/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch1/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3a_branch1/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2a/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2a/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2b/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2b/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2c/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3b_branch2c/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2a/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2a/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2b/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2b/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2c/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3c_branch2c/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2a/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2a/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2b/moving_mean:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2b/moving_variance:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2c/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn3d_branch2c/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch1/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4a_branch1/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4b_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4b_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4b_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4c_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4c_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4c_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4d_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4d_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4d_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4e_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4e_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4e_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4f_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4f_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4f_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4g_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4g_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4g_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4h_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4h_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4h_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4i_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4i_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4i_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4j_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4j_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4j_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4k_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4k_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4k_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4l_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4l_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4l_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4m_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4m_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4m_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4n_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4n_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4n_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4o_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4o_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4o_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4p_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4p_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4p_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4q_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4q_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4q_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4r_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4r_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4r_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4s_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4s_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4s_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4t_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4t_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4t_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4u_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4u_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4u_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4v_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4v_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4v_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2a/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2a/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4w_branch2b/moving_mean:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'tbn4w_branch2b/moving_variance:0' shape=(256,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2c/moving_mean:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn4w_branch2c/moving_variance:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2a/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2a/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5a_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5a_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2c/moving_mean:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch2c/moving_variance:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch1/moving_mean:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5a_branch1/moving_variance:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2a/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2a/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5b_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5b_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2c/moving_mean:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5b_branch2c/moving_variance:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2a/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2a/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5c_branch2b/moving_mean:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'tbn5c_branch2b/moving_variance:0' shape=(512,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2c/moving_mean:0' shape=(2048,) dtype=float32_ref>,
#  <tf.Variable 'bn5c_branch2c/moving_variance:0' shape=(2048,) dtype=float32_ref>]
